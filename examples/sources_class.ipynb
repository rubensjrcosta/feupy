# %%
# Licensed under a 3-clause BSD style license - see LICENSE.rst
"""Feupy Sources examples."""
# Out:
# 'Feupy Sources examples.'

# %%
from feupy.catalogs import FEUPY_CATALOG_REGISTRY

# %%
FEUPY_CATALOG_REGISTRY
# Out:
# [gammapy.catalog.gammacat.SourceCatalogGammaCat,
#  gammapy.catalog.hess.SourceCatalogHGPS,
#  gammapy.catalog.hawc.SourceCatalog2HWC,
#  gammapy.catalog.fermi.SourceCatalog3FGL,
#  gammapy.catalog.fermi.SourceCatalog4FGL,
#  gammapy.catalog.fermi.SourceCatalog2FHL,
#  gammapy.catalog.fermi.SourceCatalog3FHL,
#  gammapy.catalog.fermi.SourceCatalog3PC,
#  gammapy.catalog.hawc.SourceCatalog3HWC,
#  gammapy.catalog.fermi.SourceCatalog2PC,
#  gammapy.catalog.lhaaso.SourceCatalog1LHAASO,
#  feupy.catalogs.hawc.SourceCatalogEHWC,
#  feupy.catalogs.hawc.SourceCatalogExtraHAWC,
#  feupy.catalogs.hess.SourceCatalogExtraHESS,
#  feupy.catalogs.veritas.SourceCatalogVTSCat,
#  feupy.catalogs.veritas.SourceCatalogVERITASCygnus,
#  feupy.catalogs.psrcat.SourceCatalogPSRCAT,
#  feupy.catalogs.lhaaso.SourceCatalogLHAASO,
#  feupy.catalogs.lhaaso.SourceCatalogExtraLHAASO]

# %%
from feupy.catalogs import SourceCatalogLHAASO

# Initialize the LHAASO catalog using the provided file path
catalog = SourceCatalogLHAASO()

# Access the first source in the catalog
first_source = catalog[0]

# Print basic information about the first source
print(first_source)

# Print detailed information about the source including position and spectrum
print(first_source.info(info="all"))

# Get the sky model associated with the source
sky_model = first_source.sky_model()
print(f"Sky model: {sky_model}")

# Access the flux points of the source and print them
flux_points = first_source.flux_points
print(flux_points)

# Display the differential flux points table
flux_table = first_source.flux_points_table
print(flux_table)

# Fit a spectral model to the source
spectral_model = first_source.spectral_model()
if spectral_model:
    print(f"Fitted Spectral Model: {spectral_model}")
else:
    print("Spectral model fitting was not successful or unsupported model type.")
# Out:
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: LHAASO J0534+2202
#
# *** Position info ***
#
# RA: 83.550
# DEC: 22.050
#
# *** Spectral info ***
#
# Spectrum type: PowerLawSpectralModel
# index: 205973502.000 ± 1.999999880790721
# amplitude: 0.000 ± 5.330249237131685e-18 TeV⁻¹ s⁻¹ cm⁻²
# reference: 100.000 ± 0.0 TeV
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: LHAASO J0534+2202
#
# *** Position info ***
#
# RA: 83.550
# DEC: 22.050
#
# *** Spectral info ***
#
# Spectrum type: PowerLawSpectralModel
# index: 205973502.000 ± 1.999999880790721
# amplitude: 0.000 ± 5.330249237131685e-18 TeV⁻¹ s⁻¹ cm⁻²
# reference: 100.000 ± 0.0 TeV
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Sky model: SkyModel
#
#   Name                      : LHAASO J0534+2202
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       :
#   Temporal model type       :
#   Parameters:
#     index                         : 205973502.000  +/-    2.00
#     amplitude                     :   3.81e-17   +/- 5.3e-18 1 / (TeV s cm2)
#     reference             (frozen):    100.000       TeV
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
# ...
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# FluxPoints
# ----------
#
#   geom                   : RegionGeom
#   axes                   : ['lon', 'lat', 'energy']
#   shape                  : (1, 1, 1)
#   quantities             : ['norm', 'norm_err', 'is_ul']
#   ref. model             : pl
#   n_sigma                : 1
#   n_sigma_ul             : None
#   sqrt_ts_threshold_ul   : 2
#   sed type init          : e2dnde
#
# e_ref     e2dnde          e2dnde_err      is_ul
#  TeV  erg / (s cm2)     erg / (s cm2)
# ----- ------------- --------------------- -----
# 100.0       6.1e-13 8.540000000000001e-14 False
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Fitted Spectral Model: PowerLawSpectralModel
#
# type    name     value         unit        error   min max frozen link prior
# ---- --------- ---------- -------------- --------- --- --- ------ ---- -----
#          index 2.0597e+08                2.000e+00 nan nan  False
#      amplitude 3.8073e-17 TeV-1 s-1 cm-2 5.330e-18 nan nan  False
#      reference 1.0000e+02            TeV 0.000e+00 nan nan   True
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %%
from feupy.catalogs import SourceCatalogVTSCat

# Initialize the VTSCat catalog using the provided file path
catalog = SourceCatalogVTSCat()

# Access the first source in the catalog
second_source = catalog[0]

# Print basic information about the first source
print(second_source)

# Print detailed information about the source including position and spectrum
print(second_source.info(info="all"))

# Get the sky model associated with the source
obs_info = second_source.observation_info
print(f"Observation info: {obs_info}")

# Access the flux points of the source and print them
flux_points = second_source.flux_points
print(flux_points)

# Display the differential flux points table
flux_tables = second_source.flux_points_tables
print(flux_tables)

# Fit a spectral model to the source
second_source.reference_id_info
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/phoenix/Coding/GitHub/feupy-data/feupy-datasets/1.0/catalogs/vtscat/datasets/2013ApJ...764...38A/VER-000001.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/phoenix/Coding/GitHub/feupy-data/feupy-datasets/1.0/catalogs/vtscat/datasets/2013ApJ...764...38A/info.yaml
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: VER J0006+729
# VTSCat name: VER J0006+729
# Common name: CTA 1
# Other names: SNR G119.5+10.2
# VTSCat id: 1
# Location: gal
# Type: detected
# VTSCat components: None
# VTSCat ID name: VER-000001
# Simbad ID: CTA 1
# References: 2013ApJ...764...38A
#
#
# *** Position info ***
#
# RA: 1.650 deg
# DEC: 72.783 deg
#
#
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: VER J0006+729
# VTSCat name: VER J0006+729
# Common name: CTA 1
# Other names: SNR G119.5+10.2
# VTSCat id: 1
# Location: gal
# Type: detected
# VTSCat components: None
# VTSCat ID name: VER-000001
# Simbad ID: CTA 1
# References: 2013ApJ...764...38A
#
#
# *** Position info ***
#
# RA: 1.650 deg
# DEC: 72.783 deg
#
# Observation info:    source_id         reference_id telescope data.livetime  data.significance  \
# 0          1  2013ApJ...764...38A   veritas        41.25h                7.5
#
#    data.significance_post_trial pos.ra.val pos.ra.err pos.ra.err_sys  \
# 0                           6.5    0h6m26s      0.09d            50s
#
#    pos.dec.val  ... spec.model.parameters.norm.val  \
# 0  72d59m01.0s  ...                          0.091
#
#   spec.model.parameters.norm.err  spec.model.parameters.norm.err_sys  \
# 0                          0.013                               0.017
#
#   spec.model.parameters.norm.scale  spec.model.parameters.norm.unit  \
# 0                            1e-12                   cm-2 s-1 TeV-1
#
#   spec.model.parameters.index.val spec.model.parameters.index.err  \
# 0                             2.2                             0.2
#
#   spec.model.parameters.index.err_sys spec.model.parameters.e_ref.val  \
# 0                                 0.3                               3
#
#   spec.model.parameters.e_ref.unit
# 0                              TeV
#
# [1 rows x 38 columns]
# <bound method SourceCatalogObjectVTSCat.flux_points of <feupy.catalogs.veritas.SourceCatalogObjectVTSCat object at 0x75504f517800>>
# [<Table length=6>
#  e_ref   e_min   e_max        dnde          dnde_err    significance
#   TeV     TeV     TeV   1 / (TeV s cm2) 1 / (TeV s cm2)
# float32 float32 float32     float32         float32       float32
# ------- ------- ------- --------------- --------------- ------------
#    0.78    0.56     1.0         1.9e-12           9e-13          2.3
#    1.39     1.0    1.78         7.3e-13         1.7e-13          4.5
#    2.47    1.78    3.16         1.2e-13           4e-14          3.3
#    4.39    3.16    5.62         3.4e-14         1.2e-14          3.1
#    7.81    5.62    10.0         1.2e-14           5e-15          2.5
#   13.89    10.0   17.78         7.1e-15         2.5e-15          2.8]
#           reference_id source_id  telescope  \
# 0  2013ApJ...764...38A       [1]  [veritas]
#
#                                      multiwavelength  \
# 0  [{'content': ['rosat', 'xmm']}, {'availability...
#
#                                  datasets data_entry.status  \
# 0  [VER-000001.yaml, VER-000001-sed.ecsv]          complete
#
#    data_entry.reviewed
# 0                 True

# %%
from feupy.catalogs import SourceCatalogPSRCAT

# Initialize the VTSCat catalog using the provided file path
catalog = SourceCatalogPSRCAT()

# Access the first source in the catalog
third_source = catalog[0]

# Print basic information about the first source
print(third_source)

# Print detailed information about the source including position and spectrum
print(third_source.info(info="all"))
# Out:
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: PSR J0002+6216
#
# *** Position info ***
#
# RA: 0.742 deg ± 0.000 deg
# DEC: 62.269 deg ± 0.000 deg
#
# *** Timing and profile info ***
#
# P0: 1.154e-01 ± 1.331e-12 s
#
# *** Distance info ***
#
# Dist: 6.36e+00 kpc
# Dist_DM: 6.36e+00 kpc
#
# *** Associations and survey info ***
#
# Assoc: GRS
# Type: HE
#
# *** Derived parameters info ***
#
# Age: 3.06e+05 yr
# BSurf: 8.40e+11 G
# E_dot: 1.53e+35 erg / s
#
#
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: PSR J0002+6216
#
# *** Position info ***
#
# RA: 0.742 deg ± 0.000 deg
# DEC: 62.269 deg ± 0.000 deg
#
# *** Timing and profile info ***
#
# P0: 1.154e-01 ± 1.331e-12 s
#
# *** Distance info ***
#
# Dist: 6.36e+00 kpc
# Dist_DM: 6.36e+00 kpc
#
# *** Associations and survey info ***
#
# Assoc: GRS
# Type: HE
#
# *** Derived parameters info ***
#
# Age: 3.06e+05 yr
# BSurf: 8.40e+11 G
# E_dot: 1.53e+35 erg / s

# %%
from feupy.catalogs import SourceCatalogVERITASCygnus

# Initialize the VTSCat catalog using the provided file path
catalog = SourceCatalogVERITASCygnus()

# Access the first source in the catalog
third_source = catalog[5]

# Print basic information about the first source
print(third_source)

# Print detailed information about the source including position and spectrum
print(third_source.info(info="all"))
# Out:
# *** Basic info ***
#
# Catalog row index (zero-based) : 5
# Source name : VER J2016+371
#
# *** Position info ***
#
# RA: 303.988 deg
# DEC: 37.209 deg
#
# *** Spectral info ***
#
# Spectrum type:  PowerLawSpectralModel
# index: 2.12 +- 0.741
# amplitude: 2.78e-14 +- 1.22e-14 TeV⁻¹ s⁻¹ cm⁻²
# reference: 2.51e+03 +- 0.0 GeV
#
#
# *** Basic info ***
#
# Catalog row index (zero-based) : 5
# Source name : VER J2016+371
#
# *** Position info ***
#
# RA: 303.988 deg
# DEC: 37.209 deg
#
# *** Spectral info ***
#
# Spectrum type:  PowerLawSpectralModel
# index: 2.12 +- 0.741
# amplitude: 2.78e-14 +- 1.22e-14 TeV⁻¹ s⁻¹ cm⁻²
# reference: 2.51e+03 +- 0.0 GeV

# %%
third_source.flux_points
# Out:
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.

# %%
first_source
# Out:
# INFO:feupy.catalogs.lhaaso:Table with a single row generated from the spectral model parameters.
# INFO:gammapy.estimators.points.core:Inferred format: gadf-sed
# WARNING:gammapy.estimators.map.core:No reference model set for FluxMaps. Assuming point source with E^-2 spectrum.
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/phoenix/miniconda3/envs/feupy/lib/python3.12/site-packages/astropy/units/quantity.py:648: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# <pre>
# *** Basic info ***
#
# Catalog row index (zero-based): 0
# Source name: LHAASO J0534+2202
#
# *** Position info ***
#
# RA: 83.550
# DEC: 22.050
#
# *** Spectral info ***
#
# Spectrum type: PowerLawSpectralModel
# index: 205973502.000 ± 1.999999880790721
# amplitude: 0.000 ± 5.330249237131685e-18 TeV⁻¹ s⁻¹ cm⁻²
# reference: 100.000 ± 0.0 TeV
# </pre>

# %%
from feupy.core.sources import Sources
sources = Sources([first_source])

# %%
from feupy.catalogs.utils import get_catalog_tag

source = sources[0]
name_label = (source.name, get_catalog_tag(source))
name_label
# Out:
# ('LHAASO J0534+2202', 'LHAASO')

# %%
sources.labels
# Out:
# ['LHAASO J0534+2202 (LHAASO)']

# %%
sources.names
# Out:
# ['LHAASO J0534+2202']

# %%
sources.positions
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(83.55, 22.05)]>

# %%
sources.write(filename='sources.yaml')

# %%
sources = Sources()
sources.read(filename='sources.yaml')

# %%
sources.names
# Out:
# ['LHAASO J0534+2202']

# %%
sources.remove(0)

# %%
catalog.table
# Out:
# <Table length=6>
#  source_name        ra          dec      spectral_model
#                    deg          deg
#    bytes14       float64      float64       bytes14
# -------------- ------------ ------------ --------------
#  VER J2031+415      307.890       41.580             pl
#  VER J2019+407      304.930       40.769             pl
#  VER J2019+368      304.848       36.779             pl
# VER J2018+367*      304.706       36.736             pl
# VER J2020+368*      304.425       35.995             pl
#  VER J2016+371      303.988       37.209             pl

# %%
from feupy.catalogs import SourceCatalogExtraHESS

# Initialize the VTSCat catalog using the provided file path
catalog = SourceCatalogExtraHESS()
catalog.table
# Out:
# <Table length=1>
#  source_name      ra     dec    radius radius_core spec_type
#                  deg     deg     deg       deg
#     str14      float64 float64 float64   float64      str4
# -------------- ------- ------- ------- ----------- ---------
# HESS J1825-137 276.454 -13.776   0.800       0.400      ecpl
